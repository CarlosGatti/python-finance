# %% [markdown]
# ## Calculating the Return of Indices

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# Consider three famous American market indices – Dow Jones, S&P 500, and the Nasdaq for the period of 1st of January 2000 until today.

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^DJI', '^GSPC', '^IXIC']

ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source='yahoo', start='2021-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                     ^DJI        ^GSPC         ^IXIC
# Date
# 2021-01-04  30223.890625  3700.649902  12698.450195
# 2021-01-05  30391.599609  3726.860107  12818.959961
# 2021-01-06  30829.400391  3748.139893  12740.790039
# 2021-01-07  31041.130859  3803.790039  13067.480469
# 2021-01-08  31097.970703  3824.679932  13201.980469

# %%
ind_data.tail()
# Out:
#                     ^DJI        ^GSPC         ^IXIC
# Date
# 2021-03-09  31832.740234  3875.439941  13073.820312
# 2021-03-10  32297.019531  3898.810059  13068.830078
# 2021-03-11  32485.589844  3939.340088  13398.669922
# 2021-03-12  32778.640625  3943.340088  13319.860352
# 2021-03-15  32953.460938  3968.939941  13459.708008

# %% [markdown]
# Normalize the data to 100 and plot the results on a graph.

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize=(15, 6));
plt.show()

# %% [markdown]
# How would you explain the common and the different parts of the behavior of the three indices?

# %% [markdown]
# *****

# %% [markdown]
# Obtain the simple returns of the indices.

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1

ind_returns.tail()
# Out:
#                 ^DJI     ^GSPC     ^IXIC
# Date
# 2021-03-09  0.000953  0.014155  0.036851
# 2021-03-10  0.014585  0.006030 -0.000382
# 2021-03-11  0.005839  0.010395  0.025239
# 2021-03-12  0.009021  0.001015 -0.005882
# 2021-03-15  0.005333  0.006492  0.010499

# %% [markdown]
# Estimate the average annual return of each index.

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^DJI     0.460624
# ^GSPC    0.377925
# ^IXIC    0.333390
# dtype: float64
