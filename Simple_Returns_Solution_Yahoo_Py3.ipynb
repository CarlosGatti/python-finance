# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosGatti/python-finance/blob/main/Simple_Returns_Solution_Yahoo_Py3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Simple Returns - Part II

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# $$
# \frac{P_1 - P_0}{P_0} = \frac{P_1}{P_0} - 1
# $$

# %%
import numpy as np
from pandas_datareader import data as wb
MSFT = wb.DataReader('MSFT', data_source='yahoo', start='2021-1-1')
MSFT['simple_return'] = (MSFT['Adj Close'] / MSFT['Adj Close'].shift(1)) - 1
print (MSFT['simple_return'])
# Out:
# Date
# 2021-01-04         NaN
# 2021-01-05    0.000965
# 2021-01-06   -0.025929
# 2021-01-07    0.028457
# 2021-01-08    0.006093
# 2021-01-11   -0.009699
# 2021-01-12   -0.011771
# 2021-01-13    0.006560
# 2021-01-14   -0.015346
# 2021-01-15   -0.001737
# 2021-01-19    0.017823
# 2021-01-20    0.036500
# 2021-01-21    0.002808
# 2021-01-22    0.004356
# 2021-01-25    0.015844
# 2021-01-26    0.012199
# 2021-01-27    0.002453
# 2021-01-28    0.025891
# 2021-01-29   -0.029172
# 2021-02-01    0.033152
# 2021-02-02   -0.000584
# 2021-02-03    0.014571
# 2021-02-04   -0.004074
# 2021-02-05    0.000785
# 2021-02-08    0.001115
# 2021-02-09    0.005361
# 2021-02-10   -0.003897
# 2021-02-11    0.006877
# 2021-02-12    0.002045
# 2021-02-16   -0.005266
# 2021-02-17    0.004360
# 2021-02-18   -0.001679
# 2021-02-19   -0.011567
# 2021-02-22   -0.026808
# 2021-02-23   -0.005288
# 2021-02-24    0.005487
# 2021-02-25   -0.023705
# 2021-02-26    0.014804
# 2021-03-01    0.019623
# 2021-03-02   -0.012957
# 2021-03-03   -0.026981
# 2021-03-04   -0.003647
# 2021-03-05    0.021479
# 2021-03-08   -0.018178
# 2021-03-09    0.028101
# 2021-03-10   -0.005817
# 2021-03-11    0.020265
# 2021-03-12   -0.005820
# 2021-03-15   -0.003987
# Name: simple_return, dtype: float64

# %% [markdown]
# Plot the simple returns on a graph.

# %%
import matplotlib.pyplot as plt

# %%
MSFT['simple_return'].plot(figsize=(8, 5))
plt.show()

# %% [markdown]
# Calculate the average daily return.

# %%
avg_returns_d = MSFT['simple_return'].mean()
avg_returns_d
# Out:
# 0.001751409835614735

# %% [markdown]
# Estimate the average annual return.

# %%
avg_returns_a = MSFT['simple_return'].mean() * 250
avg_returns_a
# Out:
# 0.43785245890368374

# %% [markdown]
# Print the percentage version of the result as a float with 2 digits after the decimal point.

# %%
print (str(round(avg_returns_a, 4) * 100) + ' %')
# Out:
# 43.79 %
